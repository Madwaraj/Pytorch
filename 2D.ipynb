# %% [markdown]
# # Robust Neural Network: 2D toy example
#
# In this example, we train a simple network that is robust to adversarial noise.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
import seaborn
import matplotlib.patches as patches
from scipy.spatial import HalfspaceIntersection

# %matplotlib inline
seaborn.set(font_scale=2)
seaborn.set_style("white")

import numpy as np

# %%
# random points at least 2r apart
m = 12
np.random.seed(3)
x = [np.random.uniform(size=(2))]
r = 0.16
while(len(x) < m):
    p = np.random.uniform(size=(2))
    if min(np.abs(p-a).sum() for a in x) > 2*r:
        x.append(p)
# r = 0.145
epsilon = r/2

X = torch.Tensor(np.array(x))
torch.manual_seed(1)
y = (torch.rand(m)+0.5).long()

# %% [markdown]
# ## Baseline: cross entropy loss

# %%
net = nn.Sequential(
    nn.Linear(2,100),
    nn.ReLU(),
    nn.Linear(100,100),
    nn.ReLU(),
    nn.Linear(100,100),
    nn.ReLU(),
    nn.Linear(100,100),
    nn.ReLU(),
    nn.Linear(100,2)
)

opt = optim.Adam(net.parameters(), lr=1e-3)
for i in range(1000):
    out = net(Variable(X))
    l = nn.CrossEntropyLoss()(out, Variable(y))
    err = (out.max(1)[1].data != y).float().mean()
    if i % 100 == 0:
        print(l.data, err)
    opt.zero_grad()
    (l).backward()
    opt.step()
print(l.data)
# Out:
# tensor(0.6952) tensor(0.7500)
# tensor(0.0421) tensor(0.)
# tensor(0.0008) tensor(0.)
# tensor(0.0003) tensor(0.)
# tensor(0.0002) tensor(0.)
# tensor(0.0001) tensor(0.)
# tensor(3.9864e-05) tensor(0.)
# tensor(1.1325e-05) tensor(0.)
# tensor(6.2187e-06) tensor(0.)
# tensor(4.1723e-06) tensor(0.)
# tensor(3.1193e-06)

# %% [markdown]
# ### Visualization: learned baseline classifier

# %%
XX, YY = np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100))
X0 = Variable(torch.Tensor(np.stack([np.ravel(XX), np.ravel(YY)]).T))
y0 = net(X0)
ZZ = (y0[:,0] - y0[:,1]).resize(100,100).data.numpy()

fig, ax = plt.subplots(figsize=(8,8))
ax.contourf(XX,YY,-ZZ, cmap="coolwarm", levels=np.linspace(-1000,1000,3))
ax.scatter(X.numpy()[:,0], X.numpy()[:,1], c=y.numpy(), cmap="coolwarm", s=70)
ax.axis("equal")
ax.axis([0,1,0,1])

for a in x:
    ax.add_patch(patches.Rectangle((a[0]-r/2, a[1]-r/2), r, r, fill=False))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/torch/tensor.py:362: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")

# %% [markdown]
# ## Robust Neural Network

# %%
import sys
sys.path.append("../")
from convex_adversarial import robust_loss

torch.manual_seed(1)
robust_net = nn.Sequential(
    nn.Linear(2,100),
    nn.ReLU(),
    nn.Linear(100,100),
    nn.ReLU(),
    nn.Linear(100,100),
    nn.ReLU(),
    nn.Linear(100,100),
    nn.ReLU(),
    nn.Linear(100,2)
)
data = []
opt = optim.Adam(robust_net.parameters(), lr=1e-3)
for i in range(1000):
    robust_ce, robust_err = robust_loss(robust_net, epsilon, Variable(X), Variable(y))
    out = robust_net(Variable(X))
    l2 = nn.CrossEntropyLoss()(out, Variable(y))
    err = (out.max(1)[1].data != y).float().mean()
    data.append([l2.data, robust_ce.data, err, robust_err])
    if i % 100 == 0:
        print(robust_ce.data[0], robust_err)
    opt.zero_grad()
    (robust_ce).backward()
    opt.step()

print(l2.data, robust_ce.data, robust_err)
# Out:
# c chape =  torch.Size([12, 2, 2])
# nu shape =  torch.Size([12, 2, 100])
# Out shape =  torch.Size([12, 2, 100])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-84a774d2be50> in <module>
#      18 opt = optim.Adam(robust_net.parameters(), lr=1e-3)
#      19 for i in range(1000):
# ---> 20     robust_ce, robust_err = robust_loss(robust_net, epsilon, Variable(X), Variable(y))
#      21     out = robust_net(Variable(X))
#      22     l2 = nn.CrossEntropyLoss()(out, Variable(y))
#
# ~/Downloads/Master Thesis/convex_adversarial-0.2/convex_adversarial/dual.py in robust_loss(net, epsilon, X, y, size_average, alpha_grad, scatter_grad)
#     185     if X.is_cuda:
#     186         c = c.cuda()
# --> 187     f = -dual.g(c)
#     188     err = (f.data.max(1)[1] != y.data)
#     189     if size_average:
#
# ~/Downloads/Master Thesis/convex_adversarial-0.2/convex_adversarial/dual.py in g(self, c)
#     157                 out = nu[i].clone()
#     158                 print("Out shape = ",out.shape)
# --> 159                 out[self.I_neg[i-1].unsqueeze(1)] = 0
#     160                 if not self.I_empty[i-1]:
#     161                     if self.alpha_grad:
#
# IndexError: The shape of the mask [12, 1, 100] at index 1 does not match the shape of the indexed tensor [12, 2, 100] at index 1

# %% [markdown]
# ### Visualization: learned robust classifier

# %%
XX, YY = np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100))
X0 = Variable(torch.Tensor(np.stack([np.ravel(XX), np.ravel(YY)]).T))
y0 = robust_net(X0)
ZZ = (y0[:,0] - y0[:,1]).resize(100,100).data.numpy()

fig, ax = plt.subplots(figsize=(8,8))
ax.contourf(XX,YY,-ZZ, cmap="coolwarm", levels=np.linspace(-1000,1000,3))
ax.scatter(X.numpy()[:,0], X.numpy()[:,1], c=y.numpy(), cmap="coolwarm", s=70)
ax.axis("equal")
ax.axis([0,1,0,1])

for a in x:
    ax.add_patch(patches.Rectangle((a[0]-r/2, a[1]-r/2), r, r, fill=False))

# %% [markdown]
# # Grid plots

# %%
def plot_grid(net, ax): 
    XX, YY = np.meshgrid(np.linspace(-0.1, 1.1, 100), np.linspace(-0.1, 1.1, 100))
    X0 = Variable(torch.Tensor(np.stack([np.ravel(XX), np.ravel(YY)]).T))
    y0 = net(X0)
    ZZ = (y0[:,0] - y0[:,1]).resize(100,100).data.numpy()

    ax.contourf(XX,YY,-ZZ, cmap="coolwarm", levels=np.linspace(-1000,1000,3))
    ax.scatter(X.numpy()[:,0], X.numpy()[:,1], c=y.numpy(), cmap="coolwarm", s=70)
    ax.axis("equal")
    ax.axis([0,1,0,1])

    for a in x:
        ax.add_patch(patches.Rectangle((a[0]-r/2, a[1]-r/2), r, r, fill=False))
    ax.set_yticks([0.0, 0.5, 1.0])
#     ax.set_xticks([])

# %%
fig, axs = plt.subplots(1,2,figsize=(8,4), sharex=True, sharey=True)
plot_grid(net, axs[0])
plot_grid(robust_net, axs[1])
plt.tight_layout()
plt.savefig('2D_grid.pdf', bbox_inches='tight')

# %% [markdown]
# # Learning curves

# %%
seaborn.set_style("whitegrid")
d = np.array(data)
fig, ax_loss = plt.subplots(1,1,figsize=(4,4))
ax_loss.plot(d[:,0], color='C0')
ax_loss.plot(d[:,1], color='C1')
ax_err = ax_loss.twinx()
ax_err.plot(d[:,2], color='C2')
ax_err.plot(d[:,3], color='C3')

# %%
seaborn.set_style("whitegrid")
d = np.array(data)
fig, axs = plt.subplots(1,2,figsize=(8,4))
axs[0].semilogy(d[:,0], color='C0')
axs[0].semilogy(d[:,1], color='C1')
axs[1].plot(d[:,2], color='C2')
axs[1].plot(d[:,3], color='C3')
plt.tight_layout()
plt.savefig('2D_curves.pdf', bbox_inches='tight')

# %%
ax1 = plt.plot()
t = np.arange(0.01, 10.0, 0.01)
s1 = np.exp(t)
plt.plot(t,s1,'b-')
plt.xlabel('t (s)')
plt.ylabel('exp',color='b')

ax2 = ax1.twinx()
s2 = np.sin(2*np.pi*t)
ax2.plot(t, s2, 'r.')
plt.ylabel('sin', color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-2708ab0a7f99> in <module>()
#       7 plt.ylabel('exp',color='b')
#       8
# ----> 9 ax2 = ax1.twinx()
#      10 s2 = np.sin(2*np.pi*t)
#      11 ax2.plot(t, s2, 'r.')
#
# AttributeError: 'list' object has no attribute 'twinx'
